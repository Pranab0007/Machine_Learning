# %%
# %matplotlib inline

from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[7,6,9])
plt.show()

# %%
plt.plot([1,2,3],[7,6,9])
plt.title('Lathe Machining')
plt.xlabel('X - axis')
plt.ylabel('Y - axis')

plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')

A = [12,21,30]
B = [7,8,9]
C = [5,3,7]
D = [2,3,9]

plt.scatter(A,B, label = 'First', linewidth = 3)
plt.hist(C, label = 'Second', linewidth = 3)
plt.legend()


plt.show()
